# %% [markdown]
# ## NIM: 2501967096
# ## Nama: Ryan Bertrand

# %% [markdown]
# ## Exploratory data analysis and visualization using Python

# %% [markdown]
# ### Memuat Libraries

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Set style & figures inline
sns.set()
# %matplotlib inline

# %% [markdown]
# ### Memuat Data

# %%
confirmed_cases_data = 'time_series_covid19_confirmed_global.csv'
death_cases_data = 'time_series_covid19_deaths_global.csv'
recovery_cases_data = 'time_series_covid19_recovered_global.csv'

# Import datasets as pandas dataframes
raw_data_confirmed = pd.read_csv(confirmed_cases_data)
raw_data_deaths = pd.read_csv(death_cases_data)
raw_data_recovered = pd.read_csv(recovery_cases_data)

# %% [markdown]
# ### Kasus terkonfirmasi COVID-19

# %% [markdown]
# **Langkah selanjutnya dalam proses explorasi dan visualisai data covid-19 adalah menampilkan beberapa baris teratas, informasi, dan deskriptif statistik dataframe `raw_data_confirmed`**

# %%
raw_data_confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20  \
# 0        0        0        0  ...      120      170      174     237     273
# 1        0        0        0  ...      212      223      243     259     277
# 2        0        0        0  ...      511      584      716     847     986
# 3        0        0        0  ...      334      370      376     390     428
# 4        0        0        0  ...        7        7        7       8       8
#
# ...

# %%
raw_data_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 81 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  82 non-null     object
#  1   Country/Region  263 non-null    object
#  2   Lat             263 non-null    float64
#  3   Long            263 non-null    float64
#  4   1/22/20         263 non-null    int64
#  5   1/23/20         263 non-null    int64
#  6   1/24/20         263 non-null    int64
#  7   1/25/20         263 non-null    int64
#  8   1/26/20         263 non-null    int64
#  9   1/27/20         263 non-null    int64
#  10  1/28/20         263 non-null    int64
#  11  1/29/20         263 non-null    int64
#  12  1/30/20         263 non-null    int64
#  13  1/31/20         263 non-null    int64
#  14  2/1/20          263 non-null    int64
#  15  2/2/20          263 non-null    int64
#  16  2/3/20          263 non-null    int64
# ...

# %%
raw_data_confirmed.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  263.000000  263.000000  263.000000  263.000000  263.000000  263.000000
# mean    21.339244   22.068133    2.110266    2.486692    3.577947    5.452471
# std     24.779585   70.785949   27.434015   27.532888   34.275498   47.702207
# min    -51.796300 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.938500  -21.031300    0.000000    0.000000    0.000000    0.000000
# 50%     23.634500   20.168300    0.000000    0.000000    0.000000    0.000000
# 75%     41.178850   79.500000    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...        3/29/20  \
# count   263.000000   263.000000   263.000000   263.000000  ...     263.000000
# mean      8.053232    11.129278    21.209125    23.444867  ...    2738.174905
# ...

# %% [markdown]
# ### 1. Jumlah kasus terkonfirmasi COVID-19 berdasarkan negara (Bobot: 15%)

# %% [markdown]
# **Informasi diatas masih sangat general sehingga anda perlu mendapatkan informasi yang lebih spesifik, salah satunya mendapatkan informasi jumlah kasus terkonfirmasi COVID-19 berdasarkan kriteria tertentu. Anda perlu menampilkan dataframe`confirmed_country`yang berisi jumlah kasus terkonfirmasi COVID-19 di setiap negara berdasarkan deret waktu(time series) yang terindeks berdasarkan waktu(date/time) bukan berdasarkan `Country/Region`**.

# %%
dftemp = raw_data_confirmed.copy()
del dftemp["Province/State"]
del dftemp["Lat"]
del dftemp["Long"]
dfPerCountry = dftemp.groupby(["Country/Region"]).sum()
df_t = dfPerCountry.T
df_t = df_t.reset_index()
df_t = df_t.rename({'index':'Date'}, axis=1)
df_t = df_t.set_index('Date')
df_t
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# Date
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 4/3/20                  281      304     1171      439       8
# 4/4/20                  299      333     1251      466      10
# 4/5/20                  349      361     1320      501      14
# 4/6/20                  367      377     1423      525      16
# 4/7/20                  423      383     1468      545      17
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# Date
# 1/22/20                           0          0        0          0        0
# ...

# %% [markdown]
# ##### Tuliskan analisis anda berdasarkan hasil diatas:
# Dengan data frame yang sudah ditampilkan di atas kita dapat melihat jumlah kasus terkonfirmasi COVID-19 dari semua negara yang ada dalam raw_data_confirmed mulai tanggal 1/22/20 sampai 4/7/20 secara detail per harinya.

# %% [markdown]
# ### 2. Visualisasi kasus terkonfirmasi COVID-19 berdasarkan negara (Bobot: 15%)

# %% [markdown]
# **Anda sudah memiliki sebuah dataframe yang berisi kasus terkonfirmasi COVID-19 yang terindeks berdasarkan waktu. Selanjutnya, visualisasikan data jumlah kasus terkonfirmasi di negara-negara berikut (Prancis, Spanyol, Cina, AS, Italia, dan Australia). Berikan judul, labels, dan spesifikasi (ukuran, warna, ketebalan, dll) yang sesuai, sehingga plot yang dihasilkan rapi, menarik, dan mudah dipahami.**

# %%
#type your codes here
df_pilihan = df_t[["France","Spain","China","US","Italy","Australia"]]
df_pilihan.plot()
plt.title("Kasus Terkonfirmasi COVID-19 Berdasarkan Negara")
plt.xlabel("Tanggal")
plt.ylabel("Jumlah Terkonfirmasi")
# Out:
# Text(0, 0.5, 'Jumlah Terkonfirmasi')

# %% [markdown]
# ##### Tuliskan analisis anda berdasarkan hasil visualisasi diatas:
# Sesuai plot di atas kita dapat melihat kasus terkonfirmasi COVID-19 berdasarkan 6 negara yaitu France, Spain, China, US, Italy, dan Australia. Rata-rata negara France, Spain, US, dan Italy mengalami kenaikan pada bulan ke-3, China adalah negara yang tercepat terkonfirmasi COVID-19 pada bulan Januari karena COVID-19 berasal dari China sehingga wajar kalau China adalah negara pertama yang terkonfirmasi COVID-19. Australia adalah negara yang jumlah kasus terkonfirmasi COVID-19 paling sedikit dan US kebalikan dari Australia yang kasus terkonfirmasi COVID bergerak naik yang signifikan sampai 4/7/20.

# %% [markdown]
# ### 3. Jumlah kasus kematian COVID-19 yang dilaporkan berdasarkan negara (Bobot: 15%)

# %% [markdown]
# **Selain informasi kasus terkonfirmasi, anda juga perlu mendapatkan informasi mengenai kasus kematian COVID-19. Tampilkan beberapa baris teratas/terbawah beserta informasi dari dataframe `raw_data_deaths`**

# %%
# Beberapa baris teratas/terbawah dari dataframe raw_data_death 

# type your codes here
raw_data_deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20  \
# 0        0        0        0  ...        4        4        4       4       6
# 1        0        0        0  ...       10       11       15      15      16
# 2        0        0        0  ...       31       35       44      58      86
# 3        0        0        0  ...        6        8       12      14      15
# 4        0        0        0  ...        2        2        2       2       2
#
# ...

# %%
raw_data_deaths.tail()
# Out:
#                   Province/State         Country/Region       Lat       Long  \
# 258  Falkland Islands (Malvinas)         United Kingdom -51.79630 -59.523600
# 259    Saint Pierre and Miquelon                 France  46.88520 -56.315900
# 260                          NaN            South Sudan   6.87700  31.307000
# 261                          NaN         Western Sahara  24.21550 -12.885800
# 262                          NaN  Sao Tome and Principe   0.18636   6.613081
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/29/20  \
# 258        0        0        0        0        0        0  ...        0
# 259        0        0        0        0        0        0  ...        0
# 260        0        0        0        0        0        0  ...        0
# 261        0        0        0        0        0        0  ...        0
# 262        0        0        0        0        0        0  ...        0
#
# ...

# %%
# informasi dataframe raw_data_death

# type your codes here
raw_data_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 81 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  82 non-null     object
#  1   Country/Region  263 non-null    object
#  2   Lat             263 non-null    float64
#  3   Long            263 non-null    float64
#  4   1/22/20         263 non-null    int64
#  5   1/23/20         263 non-null    int64
#  6   1/24/20         263 non-null    int64
#  7   1/25/20         263 non-null    int64
#  8   1/26/20         263 non-null    int64
#  9   1/27/20         263 non-null    int64
#  10  1/28/20         263 non-null    int64
#  11  1/29/20         263 non-null    int64
#  12  1/30/20         263 non-null    int64
#  13  1/31/20         263 non-null    int64
#  14  2/1/20          263 non-null    int64
#  15  2/2/20          263 non-null    int64
#  16  2/3/20          263 non-null    int64
# ...

# %% [markdown]
# ##### Tuliskan analisis anda berdasarkan hasil diatas:
# Berdasarkan informasi yang didapat, maka dapat dianalisa sebagai berikut:
# 1. Data raw_data_deaths terdapat 263 baris dimulai dari index 0 hingga 262.
# 2. Data raw_data_deaths terdapat 81 kolom.
# 3. Pada kolom province/state terdapat 82 baris yang terisi dimana sisanya adalah kosong, setiap data dalam kolom ini berupa object yang berbentuk string.
# 4. Pada kolom Country/Region terdapat 263 baris, setiap data dalam kolom ini berupa object yang berbentuk string.
# 5. Pada kolom Lat dan Long terdapat 263 baris, setiap data dalam kolom ini berupa float.
# 6. Pada kolom 1/22/20 sampai kolom 4/7/20 terdapat 263 baris, setiap data dalam kolom ini berupa integer.

# %% [markdown]
# **Selanjutnya, tampilkan beberapa baris teratas/terbawah data kasus kematian COVID-19 di setiap negara yang terindeks berdasarkan waktu(date/time) bukan berdasarkan `Country/Region`.**

# %%
# type your codes here
dftemp_death = raw_data_deaths.copy()
del dftemp_death["Province/State"]
del dftemp_death["Lat"]
del dftemp_death["Long"]
dfPerCountry_death = dftemp_death.groupby(["Country/Region"]).sum()
df_t_death = dfPerCountry_death.T
df_t_death = df_t_death.reset_index()
df_t_death = df_t_death.rename({'index':'Date'}, axis=1)
df_t_death = df_t_death.set_index('Date')
df_t_death.head()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# Date
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# Date
# 1/22/20                           0          0        0          0        0
# 1/23/20                           0          0        0          0        0
# 1/24/20                           0          0        0          0        0
# 1/25/20                           0          0        0          0        0
# 1/26/20                           0          0        0          0        0
#
# Country/Region  ...  United Arab Emirates  United Kingdom  Uruguay  \
# Date            ...
# ...

# %%
df_t_death.tail()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# Date
# 4/3/20                    6       17      105       16       2
# 4/4/20                    7       20      130       17       2
# 4/5/20                    7       20      152       18       2
# 4/6/20                   11       21      173       21       2
# 4/7/20                   14       22      193       22       2
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# Date
# 4/3/20                            0         39        7         28      168
# 4/4/20                            0         43        7         30      186
# 4/5/20                            0         44        7         35      204
# 4/6/20                            0         48        8         40      220
# 4/7/20                            1         56        8         45      243
#
# Country/Region  ...  United Arab Emirates  United Kingdom  Uruguay  \
# Date            ...
# ...

# %%
# type your codes to check out the index here
df_t_death.index
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20',
#        '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20',
#        '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20',
#        '4/7/20'],
#       dtype='object', name='Date')

# %% [markdown]
# ##### Tuliskan analisis anda disini:
# Dari data frame diatas kita dapat melihat 5 Date teratas dan 5 Date terbawah dari data kasus kematian COVID-19 dari semua negara yang ada dalam raw_data_deaths dan kita dapat melihat index Date yang setiap datanya berupa object yang berbentuk string.

# %% [markdown]
# ### 4. Penyelarasan kurva pertumbuhan seluruh negara dengan jumlah kasus kematian COVID-19 ≥ 25 (Bobot: 25%)

# %% [markdown]
# **Untuk mendapatkan gambaran perkembangan kasus covid-19 di berbagai negara, diperlukan penyelarasan kurva pertumbuhan setiap negara. Kurva hanya menampilkan informasi yang dimulai dengan hari dimana data kasus kematian COVID-19 setidaknya 25 orang.**

# %%
#type your codes here
dftemp_death25 = raw_data_deaths.copy()
dftemp_death25
del dftemp_death25["Province/State"]
del dftemp_death25["Lat"]
del dftemp_death25["Long"]
dfPerCountry_death25 = dftemp_death25.groupby(["Country/Region"]).sum()
dfPerCountry_death25

df = None
for i in dfPerCountry_death25.columns:
    negara  = dfPerCountry_death25.index.tolist()
    tanggal = [i]*len(negara)
    jumlah  = dfPerCountry_death25[i].tolist()
    raw_data = {'Country/Region': negara,'Date': tanggal, 'Total Kematian':jumlah}
    dftgl = pd.DataFrame(raw_data)
    df = pd.concat([df,dftgl],axis = 0)
dfnegaratgl = df.groupby(["Country/Region","Date"]).sum()
dfplot = dfnegaratgl[dfnegaratgl["Total Kematian"]>=25]
dfplot
# Out:
#                         Total Kematian
# Country/Region Date
# Algeria        3/26/20              25
#                3/27/20              26
#                3/28/20              29
#                3/29/20              31
#                3/30/20              35
# ...                                ...
# United Kingdom 4/3/20             3611
#                4/4/20             4320
#                4/5/20             4943
#                4/6/20             5385
#                4/7/20             6171
#
# [837 rows x 1 columns]

# %% [markdown]
# ##### Tuliskan analisis anda disini:
# Dari data frame di atas, kita dapat melihat pada tanggal berapa negara tersebut yang jumlah kematiannya minimal 25 orang dalam 1 hari, jika ada negara yang tidak mencapai 25 maka negara tersebut tidak ditampilkan.

# %% [markdown]
# **Visualisasikan hasil diatas dan berikan/atur judul, labels, dan spesifikasi (ukuran, warna, ketebalan, dll) yang sesuai sehingga plot/kurva yang dihasilkan rapi, menarik, dan mudah dipahami.**

# %%
#plot time series
# type your codes here
listnegara = set(df['Country/Region'].tolist())
listnegara
for namanegara in listnegara:
    dfpernegara = df[(df['Country/Region']==namanegara) & (df['Total Kematian']>25)][["Date",'Total Kematian']]
    if len(dfpernegara)>0:
        dfpernegara.set_index("Date").plot()
        plt.title("Kasus Kematian COVID-19 Negara " + namanegara )
        plt.xlabel("Tanggal")
        plt.ylabel("Jumlah Kematian")
# Out:
# C:\Users\ryan8\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# ##### Tuliskan analisis anda disini:
# Kita dapat melihat visualisasi dari negara-negara yang kasus kematian akibat COVID-19 minimal 25 dan rata-rata tiap negara tersebut mengalami kenaikan sampai tanggal 4/7/20.

# %% [markdown]
# ### 5. Visualisasi jumlah pasien yang sembuh (recovered people) (Bobot: 25%)
#
# **Anda perlu mendapatkan informasi mengenai total pasien COVID-19 yang dinyatakan sembuh seperti pada kasus terkonfirmasi dan kasus kematian tapi, kali ini lakukan hal tersebut dengan membuat `user-defined functions` yang diperlukan bukan mengetik ulang barisan code yang sama seperti di nomor sebelumnya.**

# %%
#type your function codes here
def cleaning_data():
    dftemp_recovered = raw_data_recovered.copy()
    del dftemp_recovered["Province/State"]
    del dftemp_recovered["Lat"]
    del dftemp_recovered["Long"]
    dfPerCountry_recovered = dftemp_recovered.groupby(["Country/Region"]).sum() 
    return dfPerCountry_recovered  

def calculate_for_all_date(dfpcr):
    dfsum = dfpcr.sum(axis=1).sort_values(ascending=False)
    return dfsum

def calculate_total(dfsum):
    return dfsum.sum()

def display_summary(dfdetail, total):
    print("LAPORAN TOTAL SEMBUH PER NEGARA")
    for index, val in dfdetail.iteritems():
        if val>0:
            print(index," = ", val)
    print("\nLAPORAN NEGARA YANG BELUM ADA YANG SEMBUH")
    for index,val in dfdetail.iteritems():
        if val==0:
            print(index," = ", val)
    print()
    print("Total Sembuh semuanya : ", total)

# %% [markdown]
# **Periksa fungsi-fungsi yang sudah anda buat**

# %%
# write your codes to check your functions here
dfpcr = cleaning_data()
dfsum = calculate_for_all_date(dfpcr)
total = calculate_total(dfsum)
display_summary(dfsum,total)
# Out:
# LAPORAN TOTAL SEMBUH PER NEGARA
# India  =  4859387857
# Brazil  =  3412350387
# Russia  =  1128064202
# Turkey  =  919259007
# Italy  =  759237934
# Colombia  =  735029503
# Argentina  =  711610324
# Germany  =  695248246
# Iran  =  522325591
# Mexico  =  498203576
# US  =  496971828
# Poland  =  487412435
# Peru  =  458397918
# South Africa  =  433216733
# Ukraine  =  382658549
# Indonesia  =  363942501
# Czechia  =  317365660
# Chile  =  316380403
# Canada  =  264248368
# Iraq  =  250454579
# Philippines  =  232764917
# Romania  =  221738944
# Pakistan  =  206507371
# Israel  =  198086041
# Bangladesh  =  190856309
# Portugal  =  177063502
# Saudi Arabia  =  146131996
# Morocco  =  132346459
# Austria  =  131744371
# Japan  =  129683074
# Jordan  =  128718145
# United Arab Emirates  =  118844069
# Hungary  =  111425995
# Nepal  =  98893289
# France  =  96506536
# Malaysia  =  94234855
# Kazakhstan  =  91195356
# Panama  =  90821411
# Lebanon  =  90560589
# Ecuador  =  89535763
# ...

# %% [markdown]
# **Selanjutnya,tampilkan data total pasien COVID-19 yang sembuh dalam bentuk grafik yang sesuai. Berikan judul, labels, dan spesifikasi (ukuran, warna, ketebalan, dll) yang sesuai sehingga plot yang dihasilkan rapi, menarik, dan mudah dipahami.**

# %%
#type your codes here
dftemp_recovered = raw_data_recovered.copy()
del dftemp_recovered["Province/State"]
del dftemp_recovered["Lat"]
del dftemp_recovered["Long"]
del dftemp_recovered["Country/Region"]

dftemp_recovered.sum().plot()
plt.title("Total Pasien COVID-19 Yang Sembuh")
plt.xlabel("Tanggal")
plt.ylabel("Jumlah Sembuh")
# Out:
# Text(0, 0.5, 'Jumlah Sembuh')

# %% [markdown]
# ##### Tuliskan analisis anda berdasarkan hasil visualisasi diatas:
# Dengan visualisasi di atas, kita dapat mengetahui bahwa pasien yang sembuh dari COVID-19 di mulai sebelum tanggal 5/1/20 dan terus mengalami peningkatan yang cukup pesat dan menyentuh angka lebih dari 120.000.000(1,2 x 10^8) dan mengalami penurunan yang drastis sampai menyentuh angka 0 dalam beberapa bulan setelah tanggal 6/5/21.

# %% [markdown]
# **Lakukan visualisasi yang sama pada beberapa negara berikut (France, Spain, China, US, Italy, and Australia). Berikan judul, labels, dan spesifikasi (ukuran, warna, ketebalan, dll) yang sesuai sehingga plot yang dihasilkan rapi, menarik, dan mudah dipahami.**

# %%
#type your codes here
dftemp_recovered = raw_data_recovered.copy()
del dftemp_recovered["Province/State"]
del dftemp_recovered["Lat"]
del dftemp_recovered["Long"]
dfPerCountry_recovered = dftemp_recovered.groupby(["Country/Region"]).sum()
df_t_recovered = dfPerCountry_recovered.T
df_t_recovered = df_t_recovered.reset_index()
df_t_recovered = df_t_recovered.rename({'index':'Date'}, axis=1)
df_t_recovered = df_t_recovered.set_index('Date')
df_pilihan_recovered = df_t_recovered[["France","Spain","China","US","Italy","Australia"]]
df_pilihan_recovered.plot()
plt.title("Kasus Sembuh COVID-19 berdasarkan Negara")
plt.xlabel("Tanggal")
plt.ylabel("Jumlah Sembuh")
# Out:
# Text(0, 0.5, 'Jumlah Sembuh')

# %% [markdown]
# ##### Tuliskan analisis anda berdasarkan hasil visualisasi diatas:
# Berdasarkan hasil visualisasi di atas, kita dapat mengetahui bahwa US adalah negara yang kasus sembuh dari COVID-19 paling tinggi sampai menyentuh 6.000.000(6 x 10^6) kasus sembuh dalam 1 hari dan Italy adalah negara negara kedua yang tingkat jumlah kasus sembuh dari COVID-19 lebih tinggi dari France, Spain, China, dan Australia. France, Spain, dan China kasus sembuh dari COVID-19 tergolong lambat tetapi terus mengalami kenaikan tiap harinya. Australia adalah negara yang paling sedikit kasus sembuhnya.
